# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import random

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import glob
import os
from datetime import datetime

import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

# %%
now = datetime.now()

#TRAIN_IMG_SRC_FOLDER = '/./lung-segmentation/uniq'
# FOLDER_TEST = "3D-views-script"
FOLDER_TEST = "axis_images_tf12"
TRAIN_IMG_SRC_FOLDER = "/home/guilherme/Documents/noa/cidia19/data/3d-input/" + FOLDER_TEST
LIST_IMG_FOLDERS = ["exame1", "exame6", "exame11", "exame12", 
                    "exame2", "exame7", "exame13", "exame14", 
                    "exame3", "exame8", "exame15", "exame16", 
                    "exame4", "exame9", "exame17", "exame18", 
                    "exame5", "exame10", "exame19", "exame20", "exame21"]
TRAIN_IMG_FOLDERS = {
    "exame1": "healthy", # 0
    "exame6": "others",  # 0
    "exame11": "covid",
    "exame12": "covid",
    "exame2": "healthy", # 1
    "exame7": "others",
    "exame13": "covid",
    "exame14": "covid",
    "exame3": "healthy", # 2
    "exame8": "others",
    "exame15": "covid",
    "exame16": "covid",
    "exame4": "healthy", # 3
    "exame9": "others",
    "exame17": "covid",
    "exame18": "covid",
    "exame5": "healthy", # 4
    "exame10": "others",
    "exame19": "covid",
    "exame20": "covid",
    "exame21": "covid"
}

VALIDATION_IMG_SRC_FOLDER = "/home/guilherme/Documents/noa/cidia19/data/3d-input/" + FOLDER_TEST
VALIDATION_IMG_FOLDERS = {
#     "exame5": "healthy",
#     "exame15": "covid",
#     "exame10": "others"
}
SUB_FILE = ['axis1', 'axis2', 'axis3', 'axis4']

# EXAM_SLICE = 200
CLASSES = len(set([label for label in TRAIN_IMG_FOLDERS.values()]))
EPOCHS = 25
IMG_HEIGHT = 200
IMG_WIDTH = 200
IMG_CHANNELS = 3
SELECTED_MODEL = 'simple'

# %%
def get_file_path(folder, search_filter=''):
    paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)
            if search_filter in path:
                paths.append(path)
    return paths

def get_data_set(set_number, cur_subfile):
    dfs = []
    train_images = {"id": [], "label": []}
    validation_images = {"id": [], "label": []}
    subset_imgs_folder_val = LIST_IMG_FOLDERS[set_number * 4:(set_number+1) * 4]
    
    TRAIN_IMG_FOLDERS_SLICE = {}
    for img_folder in LIST_IMG_FOLDERS:
        if img_folder not in subset_imgs_folder_val:
            TRAIN_IMG_FOLDERS_SLICE[img_folder] = TRAIN_IMG_FOLDERS[img_folder]
        
    VALIDATION_IMG_FOLDERS_SLICE = {}
    for img_folder in subset_imgs_folder_val:
        VALIDATION_IMG_FOLDERS_SLICE[img_folder] = TRAIN_IMG_FOLDERS[img_folder]
    
#     print(TRAIN_IMG_FOLDERS_SLICE)
#     print(VALIDATION_IMG_FOLDERS_SLICE)
    
    df_config = [
        (TRAIN_IMG_SRC_FOLDER, TRAIN_IMG_FOLDERS_SLICE, train_images),
        (VALIDATION_IMG_SRC_FOLDER, VALIDATION_IMG_FOLDERS_SLICE, validation_images)
    ]
    for (base, folder, dic) in df_config:
        for img_folder, img_label in folder.items():
            search_folder = "{}/{}".format(base, img_folder)
            imgs_filename = sorted(get_file_path(search_folder, search_filter = cur_subfile))
            dic["id"].extend(imgs_filename)
            dic["label"].extend([img_label] * len(imgs_filename))

        dfs.append(pd.DataFrame(data=dic))

    train_df, validation_df = dfs[0], dfs[1]

    train_df.to_csv('train_df_'+str(set_number)+'.csv', index=False)
    validation_df.to_csv('validation_df_'+str(set_number)+'.csv', index=False)

    print("Train fold with {} images".format(len(train_df)))
    print(train_df.groupby("label").label.count())
    print()
    print("Validation fold with {} images".format(len(validation_df)))
    print(validation_df.groupby("label").label.count())
    print("-" * 30)
    return (train_df, validation_df)

# %%
def get_side(img, side_type, side_size=5):
    height, width, channel=img.shape
    if side_type=="horizontal":
        return np.ones((height,side_size,  channel), dtype=np.float32)*255
        
    return np.ones((side_size, width,  channel), dtype=np.float32)*255

def show_gallery(show="all"):
    n=100
    counter=0
    images=list()
    vertical_images=[]
    rng_state = np.random.get_state()
    np.random.shuffle(train_images["id"])
    np.random.set_state(rng_state)
    np.random.shuffle(train_images["label"])
    for path, target in zip(train_images["id"], train_images["label"]):
        if target!=show and show!="all":
            continue
        counter=counter+1
        if counter%100==0:
            break
        #Image loading from disk as JpegImageFile file format
        img=load_img(path, target_size=(IMG_WIDTH,IMG_HEIGHT))
        #Converting JpegImageFile to numpy array
        img=img_to_array(img)
        
        hside=get_side(img, side_type="horizontal")
        images.append(img)
        images.append(hside)

        if counter%10==0:
            himage=np.hstack((images))
            vside=get_side(himage, side_type="vertical")
            vertical_images.append(himage)
            vertical_images.append(vside)
            
            images=list()

    gallery=np.vstack((vertical_images)) 
    plt.figure(figsize=(12,12))
    plt.xticks([])
    plt.yticks([])
    title = {"all":"All Classifications's",
             "healthy":"Healthy",
             "covid":"Covid-19"}
    plt.title("100 Samples of {} Patients of the training set".format(title[show]))
    plt.imshow(gallery.astype(np.uint8))

# %%
#show_gallery("all")

# %%
def get_data_generator(dataframe, x_col, y_col, subset=None, shuffle=True, batch_size=32, class_mode="binary"):
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.05,
    horizontal_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1,
#     fill_mode='constant',
#     cval=0
    )
    
    data_generator = datagen.flow_from_dataframe(
        dataframe=dataframe,
        x_col=x_col,
        y_col=y_col,
        subset=subset,
        target_size=(IMG_WIDTH, IMG_HEIGHT),
        class_mode=class_mode,
        # color_mode="rgb",
        batch_size=batch_size,
        shuffle=shuffle
    )
    return data_generator

# %%
train_df, validation_df = get_data_set(0, SUB_FILE[0])
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = get_data_generator(example_df, "id", "label", class_mode = "categorical")
plt.figure(figsize = (12,12))
for i in range(0, 9):
        plt.subplot(3, 3, i+1)
        for X_batch, Y_batch in example_generator:
            image = X_batch[0]
            plt.imshow(image)
            break
plt.tight_layout()
plt.show()
# Out:
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1 validated image filenames belonging to 1 classes.

# %%
def get_model():
    with tf.device('/GPU:0'):
#         inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
#         s = tf.keras.layers.Lambda(lambda x: x/255)(inputs)
        
        classifier = tf.keras.Sequential()

        classifier.add(tf.keras.layers.Conv2D(32, (3, 3), input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))
#         classifier.add(MaxPooling2D(pool_size= (2,2)))

#         classifier.add(Convolution2D(64, (3, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.Conv2D(64, (3, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Conv2D(128, (3, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Flatten())

        classifier.add(tf.keras.layers.Dense(units= 512, activation= 'relu'))
        classifier.add(tf.keras.layers.Dropout(0.2))
        classifier.add(tf.keras.layers.Dense(units= 3, activation= 'sigmoid'))

        classifier.compile(optimizer= 'adam', loss= 'categorical_crossentropy' ,metrics= ['accuracy'])
        classifier.summary()

        return(classifier, 'simple')

# %%
def get_model_alexnet():
    with tf.device('/GPU:0'):
        model = tf.keras.Sequential()

        model.add(tf.keras.layers.Conv2D(96, kernel_size=(11,11), strides= 4, padding= 'valid', activation= 'relu', 
                                         input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), kernel_initializer= 'he_normal'))
        
        model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', 
                                               data_format= None))

        model.add(tf.keras.layers.Conv2D(256, kernel_size=(5,5), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))
        
        model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', 
                                               data_format= None)) 

        model.add(tf.keras.layers.Conv2D(384, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))

        model.add(tf.keras.layers.Conv2D(384, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))

        model.add(tf.keras.layers.Conv2D(256, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))

        model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', 
                                               data_format= None))

        model.add(tf.keras.layers.Flatten())
        model.add(tf.keras.layers.Dense(4096, activation= 'relu'))
        model.add(tf.keras.layers.Dense(4096, activation= 'relu'))
        model.add(tf.keras.layers.Dense(1000, activation= 'relu'))
        model.add(tf.keras.layers.Dense(units=3, activation= 'softmax'))

        model.compile(optimizer= tf.keras.optimizers.Adam(0.001), loss='categorical_crossentropy', 
                      metrics=['accuracy'])
        
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.summary()
        return(model, 'alexnet')

# %%
def get_model_vgg16():
        with tf.device('/GPU:0'):
            conv_base = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

            conv_base.trainable = True
            set_trainable = False
            for layer in conv_base.layers:
                if layer.name == 'conv3_block1_1_conv':
                    set_trainable = True
                if set_trainable:
                    layer.trainable = True
                else:
                    layer.trainable = False

            model = tf.keras.Sequential()
            model.add(conv_base)
            model.add(tf.keras.layers.GlobalAveragePooling2D())
            model.add(tf.keras.layers.Dense(units=3, activation = 'sigmoid'))

            model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=2e-5), loss='binary_crossentropy', metrics=['accuracy'])
            model.summary()
            return (model, 'vgg16')

# %%
def train_model(model, train_df, validation_df, epochs, callbacks=[]):
    batch_size = 16
    train_generator = get_data_generator(train_df, "id", "label", batch_size=batch_size, class_mode="categorical")
    validation_generator = get_data_generator(validation_df, "id", "label", batch_size=batch_size, class_mode="categorical")

    step_size_train = train_generator.n // train_generator.batch_size
    step_size_validation = validation_generator.n // validation_generator.batch_size

    if step_size_train == 0:
        step_size_train = train_generator.n // 2
        step_size_validation = validation_generator.n // 2
        
    history = model.fit(train_generator, # X_Train
        steps_per_epoch=step_size_train,
        epochs=epochs, 
        validation_data=validation_generator,
        validation_steps=step_size_validation,
        callbacks=callbacks
   )
    return history.history

# %%
def plot_results(history, sub_folder, kfold, sel_model):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']

    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()
    plt.savefig('images/' + FOLDER_TEST + '/' + sub_folder + '/' + kfold + 'acc_'  + sel_model,
                pad_inches=0.1)
    
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and Validation loss')
    plt.legend()
    
    plt.savefig('images/' + FOLDER_TEST + '/' + sub_folder + '/' + kfold + 'loss_'  + sel_model, 
                orientation='portrait', pad_inches=0.1)

    plt.show()

# %%
for cur_subfolder in SUB_FILE:
    for set_number in [0, 1, 2, 3, 4]:
        print('\n\n\nTEST #\n=====')
        print(cur_subfolder, set_number)
        train_df, validation_df = get_data_set(set_number, cur_subfolder)
        model, SELECTED_MODEL = get_model_vgg16()
        history = train_model(model, train_df, validation_df, EPOCHS)
        plot_results(history, cur_subfolder, str(set_number), SELECTED_MODEL)
# Out:
# TEST #
# =====
# axis1 0
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 23s 202ms/step - loss: 0.7585 - accuracy: 0.2357 - val_loss: 0.7404 - val_accuracy: 0.2546
# Epoch 2/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.7243 - accuracy: 0.2335 - val_loss: 0.7151 - val_accuracy: 0.2523
# Epoch 3/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.6946 - accuracy: 0.2362 - val_loss: 0.6915 - val_accuracy: 0.2523
# Epoch 4/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.6692 - accuracy: 0.2427 - val_loss: 0.6720 - val_accuracy: 0.2894
# Epoch 5/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6485 - accuracy: 0.3813 - val_loss: 0.6561 - val_accuracy: 0.3333
# Epoch 6/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6316 - accuracy: 0.5070 - val_loss: 0.6431 - val_accuracy: 0.4977
# Epoch 7/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.6178 - accuracy: 0.5286 - val_loss: 0.6339 - val_accuracy: 0.4954
# Epoch 8/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6062 - accuracy: 0.5286 - val_loss: 0.6260 - val_accuracy: 0.5000
# Epoch 9/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5981 - accuracy: 0.5286 - val_loss: 0.6188 - val_accuracy: 0.5000
# Epoch 10/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5920 - accuracy: 0.5297 - val_loss: 0.6144 - val_accuracy: 0.5000
# Epoch 11/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5869 - accuracy: 0.5297 - val_loss: 0.6129 - val_accuracy: 0.4977
# Epoch 12/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5830 - accuracy: 0.5302 - val_loss: 0.6091 - val_accuracy: 0.5000
# Epoch 13/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5807 - accuracy: 0.5291 - val_loss: 0.6073 - val_accuracy: 0.5000
# Epoch 14/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5782 - accuracy: 0.5302 - val_loss: 0.6067 - val_accuracy: 0.4977
# Epoch 15/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5762 - accuracy: 0.5297 - val_loss: 0.6047 - val_accuracy: 0.4977
# Epoch 16/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5745 - accuracy: 0.5307 - val_loss: 0.6001 - val_accuracy: 0.5069
# Epoch 17/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5729 - accuracy: 0.5297 - val_loss: 0.5997 - val_accuracy: 0.5046
# Epoch 18/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5717 - accuracy: 0.5286 - val_loss: 0.5981 - val_accuracy: 0.5069
# Epoch 19/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5688 - accuracy: 0.5307 - val_loss: 0.5976 - val_accuracy: 0.5023
# Epoch 20/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5681 - accuracy: 0.5297 - val_loss: 0.5982 - val_accuracy: 0.5023
# Epoch 21/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5665 - accuracy: 0.5297 - val_loss: 0.5974 - val_accuracy: 0.5000
# Epoch 22/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5643 - accuracy: 0.5302 - val_loss: 0.5978 - val_accuracy: 0.4954
# Epoch 23/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5629 - accuracy: 0.5286 - val_loss: 0.5936 - val_accuracy: 0.5023
# Epoch 24/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5618 - accuracy: 0.5280 - val_loss: 0.5948 - val_accuracy: 0.4977
# Epoch 25/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5591 - accuracy: 0.5297 - val_loss: 0.5916 - val_accuracy: 0.5023
# TEST #
# =====
# axis1 1
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5923 - accuracy: 0.5275 - val_loss: 0.6157 - val_accuracy: 0.5000
# Epoch 2/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5837 - accuracy: 0.5297 - val_loss: 0.6063 - val_accuracy: 0.5069
# Epoch 3/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5784 - accuracy: 0.5297 - val_loss: 0.6057 - val_accuracy: 0.5000
# Epoch 4/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5742 - accuracy: 0.5297 - val_loss: 0.6037 - val_accuracy: 0.4954
# Epoch 5/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5714 - accuracy: 0.5291 - val_loss: 0.5984 - val_accuracy: 0.5069
# Epoch 6/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5683 - accuracy: 0.5286 - val_loss: 0.5990 - val_accuracy: 0.5046
# Epoch 7/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5665 - accuracy: 0.5286 - val_loss: 0.6006 - val_accuracy: 0.5000
# Epoch 8/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5636 - accuracy: 0.5291 - val_loss: 0.5960 - val_accuracy: 0.5069
# Epoch 9/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5613 - accuracy: 0.5297 - val_loss: 0.5987 - val_accuracy: 0.5000
# Epoch 10/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5605 - accuracy: 0.5259 - val_loss: 0.5954 - val_accuracy: 0.5023
# Epoch 11/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5570 - accuracy: 0.5291 - val_loss: 0.5971 - val_accuracy: 0.5000
# Epoch 12/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5562 - accuracy: 0.5280 - val_loss: 0.5974 - val_accuracy: 0.5000
# Epoch 13/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5536 - accuracy: 0.5280 - val_loss: 0.5972 - val_accuracy: 0.5023
# Epoch 14/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5507 - accuracy: 0.5297 - val_loss: 0.5968 - val_accuracy: 0.4977
# Epoch 15/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5488 - accuracy: 0.5280 - val_loss: 0.5973 - val_accuracy: 0.5000
# Epoch 16/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5471 - accuracy: 0.5291 - val_loss: 0.5944 - val_accuracy: 0.5023
# Epoch 17/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5446 - accuracy: 0.5297 - val_loss: 0.5957 - val_accuracy: 0.5023
# Epoch 18/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5434 - accuracy: 0.5280 - val_loss: 0.5966 - val_accuracy: 0.4977
# Epoch 19/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5403 - accuracy: 0.5297 - val_loss: 0.5987 - val_accuracy: 0.4977
# Epoch 20/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5387 - accuracy: 0.5286 - val_loss: 0.5979 - val_accuracy: 0.4954
# Epoch 21/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5370 - accuracy: 0.5280 - val_loss: 0.5962 - val_accuracy: 0.5000
# Epoch 22/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5349 - accuracy: 0.5297 - val_loss: 0.5960 - val_accuracy: 0.4977
# Epoch 23/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5335 - accuracy: 0.5286 - val_loss: 0.5929 - val_accuracy: 0.5023
# Epoch 24/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5303 - accuracy: 0.5307 - val_loss: 0.5920 - val_accuracy: 0.5046
# Epoch 25/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5291 - accuracy: 0.5286 - val_loss: 0.5948 - val_accuracy: 0.5000
# TEST #
# =====
# axis1 2
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 22s 193ms/step - loss: 0.9265 - accuracy: 0.2335 - val_loss: 0.8816 - val_accuracy: 0.2477
# Epoch 2/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.8721 - accuracy: 0.2346 - val_loss: 0.8330 - val_accuracy: 0.2523
# Epoch 3/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.8225 - accuracy: 0.2352 - val_loss: 0.7957 - val_accuracy: 0.2477
# Epoch 4/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.7802 - accuracy: 0.2357 - val_loss: 0.7605 - val_accuracy: 0.2454
# Epoch 5/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.7428 - accuracy: 0.2352 - val_loss: 0.7275 - val_accuracy: 0.2523
# Epoch 6/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.7095 - accuracy: 0.2352 - val_loss: 0.7023 - val_accuracy: 0.2500
# Epoch 7/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6831 - accuracy: 0.2330 - val_loss: 0.6822 - val_accuracy: 0.2454
# Epoch 8/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6556 - accuracy: 0.2438 - val_loss: 0.6590 - val_accuracy: 0.2801
# Epoch 9/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6356 - accuracy: 0.4331 - val_loss: 0.6387 - val_accuracy: 0.3565
# Epoch 10/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6181 - accuracy: 0.5529 - val_loss: 0.6279 - val_accuracy: 0.4954
# Epoch 11/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6041 - accuracy: 0.5313 - val_loss: 0.6158 - val_accuracy: 0.5000
# Epoch 12/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5923 - accuracy: 0.5291 - val_loss: 0.6072 - val_accuracy: 0.5000
# Epoch 13/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5831 - accuracy: 0.5297 - val_loss: 0.6032 - val_accuracy: 0.4954
# Epoch 14/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5770 - accuracy: 0.5297 - val_loss: 0.5941 - val_accuracy: 0.5069
# Epoch 15/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5724 - accuracy: 0.5286 - val_loss: 0.5953 - val_accuracy: 0.4954
# Epoch 16/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5685 - accuracy: 0.5286 - val_loss: 0.5916 - val_accuracy: 0.5000
# Epoch 17/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5661 - accuracy: 0.5286 - val_loss: 0.5920 - val_accuracy: 0.5000
# Epoch 18/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5631 - accuracy: 0.5302 - val_loss: 0.5879 - val_accuracy: 0.5023
# Epoch 19/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5624 - accuracy: 0.5270 - val_loss: 0.5879 - val_accuracy: 0.5000
# Epoch 20/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5604 - accuracy: 0.5286 - val_loss: 0.5867 - val_accuracy: 0.5023
# Epoch 21/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5582 - accuracy: 0.5291 - val_loss: 0.5854 - val_accuracy: 0.4977
# Epoch 22/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5561 - accuracy: 0.5302 - val_loss: 0.5832 - val_accuracy: 0.5023
# Epoch 23/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5545 - accuracy: 0.5286 - val_loss: 0.5822 - val_accuracy: 0.5046
# Epoch 24/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5531 - accuracy: 0.5297 - val_loss: 0.5822 - val_accuracy: 0.5000
# Epoch 25/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5518 - accuracy: 0.5286 - val_loss: 0.5839 - val_accuracy: 0.4954
# TEST #
# =====
# axis1 3
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.7898 - accuracy: 0.2346 - val_loss: 0.7663 - val_accuracy: 0.2477
# Epoch 2/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.7455 - accuracy: 0.2362 - val_loss: 0.7271 - val_accuracy: 0.2500
# Epoch 3/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.7073 - accuracy: 0.2476 - val_loss: 0.6947 - val_accuracy: 0.2523
# Epoch 4/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6760 - accuracy: 0.3689 - val_loss: 0.6673 - val_accuracy: 0.3287
# Epoch 5/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6504 - accuracy: 0.4984 - val_loss: 0.6469 - val_accuracy: 0.4560
# Epoch 6/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6295 - accuracy: 0.5270 - val_loss: 0.6274 - val_accuracy: 0.4954
# Epoch 7/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6140 - accuracy: 0.5297 - val_loss: 0.6157 - val_accuracy: 0.5023
# Epoch 8/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6026 - accuracy: 0.5280 - val_loss: 0.6081 - val_accuracy: 0.5023
# Epoch 9/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5942 - accuracy: 0.5291 - val_loss: 0.6027 - val_accuracy: 0.5023
# Epoch 10/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5882 - accuracy: 0.5302 - val_loss: 0.5997 - val_accuracy: 0.5000
# Epoch 11/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5837 - accuracy: 0.5280 - val_loss: 0.5967 - val_accuracy: 0.5000
# Epoch 12/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5801 - accuracy: 0.5291 - val_loss: 0.5954 - val_accuracy: 0.5023
# Epoch 13/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5768 - accuracy: 0.5291 - val_loss: 0.5944 - val_accuracy: 0.4977
# Epoch 14/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5748 - accuracy: 0.5297 - val_loss: 0.5933 - val_accuracy: 0.5000
# Epoch 15/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5738 - accuracy: 0.5286 - val_loss: 0.5929 - val_accuracy: 0.4954
# Epoch 16/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5717 - accuracy: 0.5275 - val_loss: 0.5928 - val_accuracy: 0.4977
# Epoch 17/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5689 - accuracy: 0.5313 - val_loss: 0.5885 - val_accuracy: 0.5046
# Epoch 18/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5681 - accuracy: 0.5270 - val_loss: 0.5887 - val_accuracy: 0.5000
# Epoch 19/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5649 - accuracy: 0.5302 - val_loss: 0.5890 - val_accuracy: 0.4977
# Epoch 20/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5648 - accuracy: 0.5275 - val_loss: 0.5886 - val_accuracy: 0.4954
# Epoch 21/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5609 - accuracy: 0.5307 - val_loss: 0.5838 - val_accuracy: 0.5046
# Epoch 22/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5606 - accuracy: 0.5280 - val_loss: 0.5865 - val_accuracy: 0.4977
# Epoch 23/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5582 - accuracy: 0.5291 - val_loss: 0.5856 - val_accuracy: 0.4977
# Epoch 24/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5566 - accuracy: 0.5297 - val_loss: 0.5843 - val_accuracy: 0.5000
# Epoch 25/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5557 - accuracy: 0.5280 - val_loss: 0.5800 - val_accuracy: 0.5046
# TEST #
# =====
# axis1 4
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.7683 - accuracy: 0.2357 - val_loss: 0.7473 - val_accuracy: 0.2523
# Epoch 2/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.7310 - accuracy: 0.2433 - val_loss: 0.7136 - val_accuracy: 0.3194
# Epoch 3/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6988 - accuracy: 0.3145 - val_loss: 0.6832 - val_accuracy: 0.5625
# Epoch 4/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6718 - accuracy: 0.4876 - val_loss: 0.6586 - val_accuracy: 0.5926
# Epoch 5/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6502 - accuracy: 0.5448 - val_loss: 0.6382 - val_accuracy: 0.5093
# Epoch 6/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6312 - accuracy: 0.5383 - val_loss: 0.6251 - val_accuracy: 0.5000
# Epoch 7/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6162 - accuracy: 0.5291 - val_loss: 0.6107 - val_accuracy: 0.5000
# Epoch 8/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.6037 - accuracy: 0.5302 - val_loss: 0.6008 - val_accuracy: 0.5046
# Epoch 9/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5938 - accuracy: 0.5302 - val_loss: 0.5944 - val_accuracy: 0.5000
# Epoch 10/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5869 - accuracy: 0.5286 - val_loss: 0.5922 - val_accuracy: 0.4954
# Epoch 11/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5825 - accuracy: 0.5280 - val_loss: 0.5888 - val_accuracy: 0.4977
# Epoch 12/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5777 - accuracy: 0.5297 - val_loss: 0.5840 - val_accuracy: 0.5000
# Epoch 13/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5754 - accuracy: 0.5291 - val_loss: 0.5828 - val_accuracy: 0.5023
# Epoch 14/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5731 - accuracy: 0.5286 - val_loss: 0.5812 - val_accuracy: 0.5023
# Epoch 15/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5712 - accuracy: 0.5286 - val_loss: 0.5784 - val_accuracy: 0.5046
# Epoch 16/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5689 - accuracy: 0.5297 - val_loss: 0.5796 - val_accuracy: 0.5000
# Epoch 17/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5675 - accuracy: 0.5297 - val_loss: 0.5812 - val_accuracy: 0.4954
# Epoch 18/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5650 - accuracy: 0.5307 - val_loss: 0.5769 - val_accuracy: 0.5023
# Epoch 19/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5638 - accuracy: 0.5286 - val_loss: 0.5785 - val_accuracy: 0.4977
# Epoch 20/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5628 - accuracy: 0.5280 - val_loss: 0.5760 - val_accuracy: 0.4977
# Epoch 21/25
# 116/116 [==============================] - 22s 192ms/step - loss: 0.5610 - accuracy: 0.5291 - val_loss: 0.5739 - val_accuracy: 0.5000
# Epoch 22/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5579 - accuracy: 0.5318 - val_loss: 0.5745 - val_accuracy: 0.4977
# Epoch 23/25
# 116/116 [==============================] - 22s 191ms/step - loss: 0.5570 - accuracy: 0.5307 - val_loss: 0.5703 - val_accuracy: 0.5023
# Epoch 24/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5558 - accuracy: 0.5302 - val_loss: 0.5725 - val_accuracy: 0.4954
# Epoch 25/25
# 116/116 [==============================] - 22s 190ms/step - loss: 0.5546 - accuracy: 0.5302 - val_loss: 0.5678 - val_accuracy: 0.5023
# TEST #
# =====
# axis2 0
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 25s 211ms/step - loss: 0.6842 - accuracy: 0.5291 - val_loss: 0.6883 - val_accuracy: 0.4977
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6600 - accuracy: 0.5280 - val_loss: 0.6635 - val_accuracy: 0.4977
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6398 - accuracy: 0.5291 - val_loss: 0.6424 - val_accuracy: 0.5023
# Epoch 4/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6253 - accuracy: 0.5280 - val_loss: 0.6329 - val_accuracy: 0.4954
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6116 - accuracy: 0.5302 - val_loss: 0.6156 - val_accuracy: 0.5023
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6021 - accuracy: 0.5302 - val_loss: 0.6082 - val_accuracy: 0.5023
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5948 - accuracy: 0.5302 - val_loss: 0.6008 - val_accuracy: 0.5023
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5907 - accuracy: 0.5286 - val_loss: 0.5942 - val_accuracy: 0.5046
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5858 - accuracy: 0.5291 - val_loss: 0.5945 - val_accuracy: 0.4977
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5810 - accuracy: 0.5313 - val_loss: 0.5892 - val_accuracy: 0.5000
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5798 - accuracy: 0.5280 - val_loss: 0.5921 - val_accuracy: 0.4954
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5769 - accuracy: 0.5291 - val_loss: 0.5853 - val_accuracy: 0.5046
# Epoch 13/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5748 - accuracy: 0.5297 - val_loss: 0.5842 - val_accuracy: 0.5000
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5710 - accuracy: 0.5329 - val_loss: 0.5813 - val_accuracy: 0.5000
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5708 - accuracy: 0.5286 - val_loss: 0.5809 - val_accuracy: 0.5000
# Epoch 16/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5689 - accuracy: 0.5286 - val_loss: 0.5774 - val_accuracy: 0.5046
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5659 - accuracy: 0.5302 - val_loss: 0.5823 - val_accuracy: 0.4907
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5647 - accuracy: 0.5286 - val_loss: 0.5768 - val_accuracy: 0.4977
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5625 - accuracy: 0.5291 - val_loss: 0.5772 - val_accuracy: 0.4977
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5603 - accuracy: 0.5291 - val_loss: 0.5755 - val_accuracy: 0.4977
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5586 - accuracy: 0.5291 - val_loss: 0.5707 - val_accuracy: 0.5023
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5563 - accuracy: 0.5302 - val_loss: 0.5710 - val_accuracy: 0.4977
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5536 - accuracy: 0.5302 - val_loss: 0.5701 - val_accuracy: 0.4977
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5516 - accuracy: 0.5307 - val_loss: 0.5672 - val_accuracy: 0.4977
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5503 - accuracy: 0.5297 - val_loss: 0.5642 - val_accuracy: 0.5046
# TEST #
# =====
# axis2 1
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_7 ( (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.7208 - accuracy: 0.2352 - val_loss: 0.7098 - val_accuracy: 0.2523
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6898 - accuracy: 0.2325 - val_loss: 0.6857 - val_accuracy: 0.2477
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6617 - accuracy: 0.2362 - val_loss: 0.6610 - val_accuracy: 0.2477
# Epoch 4/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6391 - accuracy: 0.2476 - val_loss: 0.6428 - val_accuracy: 0.2731
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6211 - accuracy: 0.5005 - val_loss: 0.6308 - val_accuracy: 0.4676
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6072 - accuracy: 0.5518 - val_loss: 0.6176 - val_accuracy: 0.5023
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5959 - accuracy: 0.5291 - val_loss: 0.6093 - val_accuracy: 0.5046
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5867 - accuracy: 0.5286 - val_loss: 0.6050 - val_accuracy: 0.4931
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5809 - accuracy: 0.5270 - val_loss: 0.5994 - val_accuracy: 0.4977
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5756 - accuracy: 0.5280 - val_loss: 0.5944 - val_accuracy: 0.5023
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5706 - accuracy: 0.5302 - val_loss: 0.5928 - val_accuracy: 0.4954
# Epoch 12/25
# 116/116 [==============================] - 24s 209ms/step - loss: 0.5666 - accuracy: 0.5302 - val_loss: 0.5908 - val_accuracy: 0.5000
# Epoch 13/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5648 - accuracy: 0.5291 - val_loss: 0.5916 - val_accuracy: 0.4931
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5622 - accuracy: 0.5307 - val_loss: 0.5851 - val_accuracy: 0.5046
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5612 - accuracy: 0.5275 - val_loss: 0.5883 - val_accuracy: 0.4954
# Epoch 16/25
# 116/116 [==============================] - 24s 209ms/step - loss: 0.5576 - accuracy: 0.5302 - val_loss: 0.5840 - val_accuracy: 0.5023
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5554 - accuracy: 0.5313 - val_loss: 0.5829 - val_accuracy: 0.5023
# Epoch 18/25
# 116/116 [==============================] - 24s 209ms/step - loss: 0.5549 - accuracy: 0.5286 - val_loss: 0.5815 - val_accuracy: 0.5046
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5525 - accuracy: 0.5280 - val_loss: 0.5835 - val_accuracy: 0.5000
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5500 - accuracy: 0.5297 - val_loss: 0.5832 - val_accuracy: 0.4977
# Epoch 21/25
# 116/116 [==============================] - 24s 209ms/step - loss: 0.5477 - accuracy: 0.5297 - val_loss: 0.5798 - val_accuracy: 0.4977
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5462 - accuracy: 0.5297 - val_loss: 0.5812 - val_accuracy: 0.4931
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5431 - accuracy: 0.5307 - val_loss: 0.5775 - val_accuracy: 0.5000
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5422 - accuracy: 0.5291 - val_loss: 0.5756 - val_accuracy: 0.5046
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5406 - accuracy: 0.5297 - val_loss: 0.5768 - val_accuracy: 0.4977
# TEST #
# =====
# axis2 2
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_8 ( (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.8593 - accuracy: 0.5426 - val_loss: 0.8548 - val_accuracy: 0.5023
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.8081 - accuracy: 0.5345 - val_loss: 0.8077 - val_accuracy: 0.4954
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7620 - accuracy: 0.5329 - val_loss: 0.7650 - val_accuracy: 0.5000
# Epoch 4/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7227 - accuracy: 0.5318 - val_loss: 0.7288 - val_accuracy: 0.4977
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6885 - accuracy: 0.5297 - val_loss: 0.7020 - val_accuracy: 0.4977
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6618 - accuracy: 0.5286 - val_loss: 0.6792 - val_accuracy: 0.5023
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6383 - accuracy: 0.5297 - val_loss: 0.6609 - val_accuracy: 0.4977
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6188 - accuracy: 0.5297 - val_loss: 0.6448 - val_accuracy: 0.5023
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6046 - accuracy: 0.5291 - val_loss: 0.6346 - val_accuracy: 0.5000
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5936 - accuracy: 0.5307 - val_loss: 0.6263 - val_accuracy: 0.5046
# Epoch 11/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5851 - accuracy: 0.5297 - val_loss: 0.6200 - val_accuracy: 0.5023
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5787 - accuracy: 0.5286 - val_loss: 0.6167 - val_accuracy: 0.5046
# Epoch 13/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5718 - accuracy: 0.5313 - val_loss: 0.6173 - val_accuracy: 0.4954
# Epoch 14/25
# 116/116 [==============================] - 24s 209ms/step - loss: 0.5693 - accuracy: 0.5286 - val_loss: 0.6146 - val_accuracy: 0.4977
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5668 - accuracy: 0.5275 - val_loss: 0.6116 - val_accuracy: 0.5023
# Epoch 16/25
# 116/116 [==============================] - 24s 209ms/step - loss: 0.5628 - accuracy: 0.5307 - val_loss: 0.6121 - val_accuracy: 0.4977
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5605 - accuracy: 0.5291 - val_loss: 0.6091 - val_accuracy: 0.5000
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5586 - accuracy: 0.5297 - val_loss: 0.6098 - val_accuracy: 0.5023
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5565 - accuracy: 0.5286 - val_loss: 0.6063 - val_accuracy: 0.5046
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5543 - accuracy: 0.5297 - val_loss: 0.6041 - val_accuracy: 0.5069
# Epoch 21/25
# 116/116 [==============================] - 25s 212ms/step - loss: 0.5518 - accuracy: 0.5297 - val_loss: 0.6076 - val_accuracy: 0.5000
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5502 - accuracy: 0.5286 - val_loss: 0.6044 - val_accuracy: 0.5046
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5480 - accuracy: 0.5297 - val_loss: 0.6058 - val_accuracy: 0.5023
# Epoch 24/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5470 - accuracy: 0.5286 - val_loss: 0.6035 - val_accuracy: 0.5046
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5426 - accuracy: 0.5324 - val_loss: 0.6069 - val_accuracy: 0.4931
# TEST #
# =====
# axis2 3
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_9 ( (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.7656 - accuracy: 0.2357 - val_loss: 0.7191 - val_accuracy: 0.2523
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7290 - accuracy: 0.2352 - val_loss: 0.6873 - val_accuracy: 0.2500
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6969 - accuracy: 0.2352 - val_loss: 0.6588 - val_accuracy: 0.2523
# Epoch 4/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.6702 - accuracy: 0.2708 - val_loss: 0.6362 - val_accuracy: 0.4236
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6484 - accuracy: 0.4423 - val_loss: 0.6171 - val_accuracy: 0.6921
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6321 - accuracy: 0.5534 - val_loss: 0.6037 - val_accuracy: 0.6968
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6177 - accuracy: 0.5302 - val_loss: 0.5898 - val_accuracy: 0.5162
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6056 - accuracy: 0.5307 - val_loss: 0.5815 - val_accuracy: 0.4977
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5984 - accuracy: 0.5302 - val_loss: 0.5775 - val_accuracy: 0.4954
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5921 - accuracy: 0.5291 - val_loss: 0.5716 - val_accuracy: 0.4954
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5872 - accuracy: 0.5291 - val_loss: 0.5637 - val_accuracy: 0.5023
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5835 - accuracy: 0.5291 - val_loss: 0.5622 - val_accuracy: 0.5023
# Epoch 13/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5796 - accuracy: 0.5297 - val_loss: 0.5594 - val_accuracy: 0.5000
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5761 - accuracy: 0.5302 - val_loss: 0.5564 - val_accuracy: 0.5000
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5749 - accuracy: 0.5291 - val_loss: 0.5538 - val_accuracy: 0.5046
# Epoch 16/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5732 - accuracy: 0.5275 - val_loss: 0.5536 - val_accuracy: 0.5000
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5698 - accuracy: 0.5313 - val_loss: 0.5526 - val_accuracy: 0.5000
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5689 - accuracy: 0.5286 - val_loss: 0.5505 - val_accuracy: 0.5000
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5667 - accuracy: 0.5291 - val_loss: 0.5496 - val_accuracy: 0.5023
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5630 - accuracy: 0.5302 - val_loss: 0.5493 - val_accuracy: 0.5000
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5623 - accuracy: 0.5297 - val_loss: 0.5447 - val_accuracy: 0.5023
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5599 - accuracy: 0.5291 - val_loss: 0.5490 - val_accuracy: 0.4954
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5586 - accuracy: 0.5286 - val_loss: 0.5454 - val_accuracy: 0.4977
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5557 - accuracy: 0.5297 - val_loss: 0.5450 - val_accuracy: 0.4977
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5532 - accuracy: 0.5302 - val_loss: 0.5433 - val_accuracy: 0.5000
# TEST #
# =====
# axis2 4
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_10  (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 25s 212ms/step - loss: 0.7834 - accuracy: 0.2357 - val_loss: 0.7653 - val_accuracy: 0.2523
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7448 - accuracy: 0.2352 - val_loss: 0.7317 - val_accuracy: 0.2500
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7113 - accuracy: 0.2352 - val_loss: 0.7058 - val_accuracy: 0.2454
# Epoch 4/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6835 - accuracy: 0.2368 - val_loss: 0.6832 - val_accuracy: 0.2477
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6604 - accuracy: 0.2416 - val_loss: 0.6650 - val_accuracy: 0.2407
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6406 - accuracy: 0.3776 - val_loss: 0.6484 - val_accuracy: 0.3843
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6255 - accuracy: 0.5081 - val_loss: 0.6378 - val_accuracy: 0.5023
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6133 - accuracy: 0.5286 - val_loss: 0.6287 - val_accuracy: 0.5000
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6040 - accuracy: 0.5280 - val_loss: 0.6217 - val_accuracy: 0.4977
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5955 - accuracy: 0.5302 - val_loss: 0.6155 - val_accuracy: 0.5046
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5892 - accuracy: 0.5313 - val_loss: 0.6157 - val_accuracy: 0.4977
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5847 - accuracy: 0.5307 - val_loss: 0.6129 - val_accuracy: 0.4977
# Epoch 13/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5808 - accuracy: 0.5302 - val_loss: 0.6112 - val_accuracy: 0.4977
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5780 - accuracy: 0.5302 - val_loss: 0.6113 - val_accuracy: 0.4954
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5750 - accuracy: 0.5297 - val_loss: 0.6056 - val_accuracy: 0.5000
# Epoch 16/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5722 - accuracy: 0.5302 - val_loss: 0.6062 - val_accuracy: 0.5000
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5698 - accuracy: 0.5291 - val_loss: 0.6037 - val_accuracy: 0.5023
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5676 - accuracy: 0.5291 - val_loss: 0.6065 - val_accuracy: 0.4954
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5653 - accuracy: 0.5302 - val_loss: 0.6029 - val_accuracy: 0.5023
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5637 - accuracy: 0.5291 - val_loss: 0.6039 - val_accuracy: 0.4954
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5604 - accuracy: 0.5313 - val_loss: 0.6006 - val_accuracy: 0.5023
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5587 - accuracy: 0.5302 - val_loss: 0.6035 - val_accuracy: 0.4977
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5558 - accuracy: 0.5307 - val_loss: 0.5999 - val_accuracy: 0.4977
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5542 - accuracy: 0.5307 - val_loss: 0.6029 - val_accuracy: 0.4931
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5512 - accuracy: 0.5313 - val_loss: 0.5969 - val_accuracy: 0.5023
# TEST #
# =====
# axis3 0
# Train fold with 1870 images
# label
# ...
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5691 - accuracy: 0.5302 - val_loss: 0.5793 - val_accuracy: 0.5023
# Epoch 16/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5666 - accuracy: 0.5297 - val_loss: 0.5806 - val_accuracy: 0.5000
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5645 - accuracy: 0.5286 - val_loss: 0.5760 - val_accuracy: 0.5069
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5627 - accuracy: 0.5297 - val_loss: 0.5785 - val_accuracy: 0.4977
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5605 - accuracy: 0.5307 - val_loss: 0.5774 - val_accuracy: 0.4977
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5593 - accuracy: 0.5270 - val_loss: 0.5727 - val_accuracy: 0.5046
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5574 - accuracy: 0.5270 - val_loss: 0.5770 - val_accuracy: 0.4954
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5540 - accuracy: 0.5302 - val_loss: 0.5720 - val_accuracy: 0.5023
# Epoch 23/25
# 116/116 [==============================] - 25s 212ms/step - loss: 0.5511 - accuracy: 0.5313 - val_loss: 0.5738 - val_accuracy: 0.4954
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5493 - accuracy: 0.5313 - val_loss: 0.5713 - val_accuracy: 0.5000
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5470 - accuracy: 0.5297 - val_loss: 0.5693 - val_accuracy: 0.5023
# TEST #
# =====
# axis4 2
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_18  (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.8499 - accuracy: 0.2352 - val_loss: 0.8237 - val_accuracy: 0.2523
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.8034 - accuracy: 0.2352 - val_loss: 0.7874 - val_accuracy: 0.2454
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7614 - accuracy: 0.2362 - val_loss: 0.7499 - val_accuracy: 0.2477
# Epoch 4/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.7235 - accuracy: 0.2362 - val_loss: 0.7182 - val_accuracy: 0.2477
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6921 - accuracy: 0.2341 - val_loss: 0.6895 - val_accuracy: 0.2546
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6632 - accuracy: 0.2368 - val_loss: 0.6678 - val_accuracy: 0.2523
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6388 - accuracy: 0.2389 - val_loss: 0.6528 - val_accuracy: 0.2454
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6193 - accuracy: 0.4186 - val_loss: 0.6359 - val_accuracy: 0.3472
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6030 - accuracy: 0.6828 - val_loss: 0.6281 - val_accuracy: 0.7130
# Epoch 10/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5916 - accuracy: 0.5755 - val_loss: 0.6188 - val_accuracy: 0.4977
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5816 - accuracy: 0.5302 - val_loss: 0.6133 - val_accuracy: 0.5000
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5741 - accuracy: 0.5318 - val_loss: 0.6097 - val_accuracy: 0.5000
# Epoch 13/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5685 - accuracy: 0.5297 - val_loss: 0.6071 - val_accuracy: 0.5046
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5647 - accuracy: 0.5297 - val_loss: 0.6089 - val_accuracy: 0.4931
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5608 - accuracy: 0.5307 - val_loss: 0.6041 - val_accuracy: 0.5000
# Epoch 16/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5575 - accuracy: 0.5307 - val_loss: 0.6025 - val_accuracy: 0.5023
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5569 - accuracy: 0.5275 - val_loss: 0.6017 - val_accuracy: 0.5046
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5540 - accuracy: 0.5286 - val_loss: 0.6009 - val_accuracy: 0.5046
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5518 - accuracy: 0.5286 - val_loss: 0.6070 - val_accuracy: 0.4931
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5492 - accuracy: 0.5307 - val_loss: 0.6003 - val_accuracy: 0.5000
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5466 - accuracy: 0.5307 - val_loss: 0.6012 - val_accuracy: 0.5000
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5454 - accuracy: 0.5280 - val_loss: 0.6030 - val_accuracy: 0.5000
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5429 - accuracy: 0.5302 - val_loss: 0.6000 - val_accuracy: 0.5046
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5409 - accuracy: 0.5297 - val_loss: 0.6033 - val_accuracy: 0.4954
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5383 - accuracy: 0.5297 - val_loss: 0.6000 - val_accuracy: 0.5000
# TEST #
# =====
# axis4 3
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_19  (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.6776 - accuracy: 0.5286 - val_loss: 0.6684 - val_accuracy: 0.4977
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6563 - accuracy: 0.5280 - val_loss: 0.6483 - val_accuracy: 0.4977
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6386 - accuracy: 0.5297 - val_loss: 0.6339 - val_accuracy: 0.4954
# Epoch 4/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6267 - accuracy: 0.5275 - val_loss: 0.6212 - val_accuracy: 0.5023
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6157 - accuracy: 0.5291 - val_loss: 0.6120 - val_accuracy: 0.5023
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6088 - accuracy: 0.5291 - val_loss: 0.6074 - val_accuracy: 0.5023
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6030 - accuracy: 0.5324 - val_loss: 0.6050 - val_accuracy: 0.4977
# Epoch 8/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5999 - accuracy: 0.5280 - val_loss: 0.6011 - val_accuracy: 0.5000
# Epoch 9/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5968 - accuracy: 0.5291 - val_loss: 0.5961 - val_accuracy: 0.5023
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5947 - accuracy: 0.5291 - val_loss: 0.5943 - val_accuracy: 0.5023
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5923 - accuracy: 0.5291 - val_loss: 0.5910 - val_accuracy: 0.5069
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5892 - accuracy: 0.5291 - val_loss: 0.5933 - val_accuracy: 0.4977
# Epoch 13/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5879 - accuracy: 0.5275 - val_loss: 0.5893 - val_accuracy: 0.5023
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5855 - accuracy: 0.5291 - val_loss: 0.5886 - val_accuracy: 0.4977
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5832 - accuracy: 0.5302 - val_loss: 0.5849 - val_accuracy: 0.5023
# Epoch 16/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5801 - accuracy: 0.5302 - val_loss: 0.5873 - val_accuracy: 0.4954
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5794 - accuracy: 0.5296 - val_loss: 0.5846 - val_accuracy: 0.4977
# Epoch 18/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5781 - accuracy: 0.5286 - val_loss: 0.5823 - val_accuracy: 0.4954
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5756 - accuracy: 0.5307 - val_loss: 0.5818 - val_accuracy: 0.4977
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5734 - accuracy: 0.5297 - val_loss: 0.5760 - val_accuracy: 0.5023
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5724 - accuracy: 0.5275 - val_loss: 0.5766 - val_accuracy: 0.4977
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5701 - accuracy: 0.5297 - val_loss: 0.5729 - val_accuracy: 0.5046
# Epoch 23/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5681 - accuracy: 0.5307 - val_loss: 0.5737 - val_accuracy: 0.5000
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5661 - accuracy: 0.5297 - val_loss: 0.5697 - val_accuracy: 0.5046
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5642 - accuracy: 0.5307 - val_loss: 0.5675 - val_accuracy: 0.5069
# TEST #
# =====
# axis4 4
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 6, 6, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_20  (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 1,539
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 116/116 [==============================] - 25s 211ms/step - loss: 0.8175 - accuracy: 0.2379 - val_loss: 0.7941 - val_accuracy: 0.2523
# Epoch 2/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7724 - accuracy: 0.2891 - val_loss: 0.7551 - val_accuracy: 0.3704
# Epoch 3/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.7340 - accuracy: 0.4423 - val_loss: 0.7188 - val_accuracy: 0.6481
# Epoch 4/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6984 - accuracy: 0.5906 - val_loss: 0.6891 - val_accuracy: 0.6528
# Epoch 5/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6685 - accuracy: 0.6003 - val_loss: 0.6626 - val_accuracy: 0.5278
# Epoch 6/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6446 - accuracy: 0.5388 - val_loss: 0.6429 - val_accuracy: 0.5000
# Epoch 7/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.6244 - accuracy: 0.5302 - val_loss: 0.6244 - val_accuracy: 0.5023
# Epoch 8/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.6080 - accuracy: 0.5291 - val_loss: 0.6124 - val_accuracy: 0.5023
# Epoch 9/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5961 - accuracy: 0.5286 - val_loss: 0.6033 - val_accuracy: 0.5023
# Epoch 10/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5852 - accuracy: 0.5291 - val_loss: 0.5994 - val_accuracy: 0.4954
# Epoch 11/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5782 - accuracy: 0.5297 - val_loss: 0.5922 - val_accuracy: 0.5000
# Epoch 12/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5726 - accuracy: 0.5280 - val_loss: 0.5871 - val_accuracy: 0.5023
# Epoch 13/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5669 - accuracy: 0.5307 - val_loss: 0.5872 - val_accuracy: 0.4954
# Epoch 14/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5643 - accuracy: 0.5286 - val_loss: 0.5818 - val_accuracy: 0.5046
# Epoch 15/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5608 - accuracy: 0.5297 - val_loss: 0.5814 - val_accuracy: 0.5000
# Epoch 16/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5584 - accuracy: 0.5302 - val_loss: 0.5822 - val_accuracy: 0.4977
# Epoch 17/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5553 - accuracy: 0.5297 - val_loss: 0.5821 - val_accuracy: 0.4977
# Epoch 18/25
# 116/116 [==============================] - 24s 211ms/step - loss: 0.5535 - accuracy: 0.5291 - val_loss: 0.5793 - val_accuracy: 0.5000
# Epoch 19/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5511 - accuracy: 0.5291 - val_loss: 0.5789 - val_accuracy: 0.5000
# Epoch 20/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5495 - accuracy: 0.5280 - val_loss: 0.5771 - val_accuracy: 0.5000
# Epoch 21/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5460 - accuracy: 0.5302 - val_loss: 0.5750 - val_accuracy: 0.5023
# Epoch 22/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5454 - accuracy: 0.5297 - val_loss: 0.5746 - val_accuracy: 0.5046
# Epoch 23/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5431 - accuracy: 0.5286 - val_loss: 0.5756 - val_accuracy: 0.5000
# Epoch 24/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5411 - accuracy: 0.5280 - val_loss: 0.5739 - val_accuracy: 0.5000
# Epoch 25/25
# 116/116 [==============================] - 24s 210ms/step - loss: 0.5378 - accuracy: 0.5302 - val_loss: 0.5709 - val_accuracy: 0.5046
