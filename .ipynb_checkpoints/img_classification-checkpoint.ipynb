# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import random

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import glob
import os
from datetime import datetime

import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

# %%
now = datetime.now()

#TRAIN_IMG_SRC_FOLDER = '/./lung-segmentation/uniq'
# FOLDER_TEST = "3D-views-script"
FOLDER_TEST = "axis_images_tf19_black"
TRAIN_IMG_SRC_FOLDER = "/home/guilherme/Documents/noa/cidia19/data/3d-input/" + FOLDER_TEST
LIST_IMG_FOLDERS = ["exame1", "exame6", "exame11", "exame12", 
                    "exame2", "exame7", "exame13", "exame14", 
                    "exame3", "exame8", "exame15", "exame16", 
                    "exame4", "exame9", "exame17", "exame18", 
                    "exame5", "exame10", "exame19", "exame20", "exame21"]
TRAIN_IMG_FOLDERS = {
    "exame1": "healthy", # 0
    "exame6": "others",  # 0
    "exame11": "covid",
    "exame12": "covid",
    "exame2": "healthy", # 1
    "exame7": "others",
    "exame13": "covid",
    "exame14": "covid",
    "exame3": "healthy", # 2
    "exame8": "others",
    "exame15": "covid",
    "exame16": "covid",
    "exame4": "healthy", # 3
    "exame9": "others",
    "exame17": "covid",
    "exame18": "covid",
    "exame5": "healthy", # 4
    "exame10": "others",
    "exame19": "covid",
    "exame20": "covid",
    "exame21": "covid"
}

VALIDATION_IMG_SRC_FOLDER = "/home/guilherme/Documents/noa/cidia19/data/3d-input/" + FOLDER_TEST
VALIDATION_IMG_FOLDERS = {
#     "exame5": "healthy",
#     "exame15": "covid",
#     "exame10": "others"
}
SUB_FILE = ['axis1', 'axis2', 'axis3', 'axis4']

# EXAM_SLICE = 200
CLASSES = len(set([label for label in TRAIN_IMG_FOLDERS.values()]))
EPOCHS = 50
IMG_HEIGHT = 200
IMG_WIDTH = 200
IMG_CHANNELS = 3
SELECTED_MODEL = 'simple'

# %%
def get_file_path(folder, search_filter=''):
    paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)
            if search_filter in path:
                paths.append(path)
    return paths

def get_data_set(set_number, cur_subfile):
    dfs = []
    train_images = {"id": [], "label": []}
    validation_images = {"id": [], "label": []}
    subset_imgs_folder_val = LIST_IMG_FOLDERS[set_number * 4:(set_number+1) * 4]
    
    TRAIN_IMG_FOLDERS_SLICE = {}
    for img_folder in LIST_IMG_FOLDERS:
        if img_folder not in subset_imgs_folder_val:
            TRAIN_IMG_FOLDERS_SLICE[img_folder] = TRAIN_IMG_FOLDERS[img_folder]
        
    VALIDATION_IMG_FOLDERS_SLICE = {}
    for img_folder in subset_imgs_folder_val:
        VALIDATION_IMG_FOLDERS_SLICE[img_folder] = TRAIN_IMG_FOLDERS[img_folder]
    
#     print(TRAIN_IMG_FOLDERS_SLICE)
#     print(VALIDATION_IMG_FOLDERS_SLICE)
    
    df_config = [
        (TRAIN_IMG_SRC_FOLDER, TRAIN_IMG_FOLDERS_SLICE, train_images),
        (VALIDATION_IMG_SRC_FOLDER, VALIDATION_IMG_FOLDERS_SLICE, validation_images)
    ]
    for (base, folder, dic) in df_config:
        for img_folder, img_label in folder.items():
            search_folder = "{}/{}".format(base, img_folder)
            imgs_filename = sorted(get_file_path(search_folder, search_filter = cur_subfile))
            dic["id"].extend(imgs_filename)
            dic["label"].extend([img_label] * len(imgs_filename))

        dfs.append(pd.DataFrame(data=dic))

    train_df, validation_df = dfs[0], dfs[1]

    train_df.to_csv('train_df_'+str(set_number)+'.csv', index=False)
    validation_df.to_csv('validation_df_'+str(set_number)+'.csv', index=False)

    print("Train fold with {} images".format(len(train_df)))
    print(train_df.groupby("label").label.count())
    print()
    print("Validation fold with {} images".format(len(validation_df)))
    print(validation_df.groupby("label").label.count())
    print("-" * 30)
    return (train_df, validation_df)

# %%
def get_side(img, side_type, side_size=5):
    height, width, channel=img.shape
    if side_type=="horizontal":
        return np.ones((height,side_size,  channel), dtype=np.float32)*255
        
    return np.ones((side_size, width,  channel), dtype=np.float32)*255

def show_gallery(show="all"):
    n=100
    counter=0
    images=list()
    vertical_images=[]
    rng_state = np.random.get_state()
    np.random.shuffle(train_images["id"])
    np.random.set_state(rng_state)
    np.random.shuffle(train_images["label"])
    for path, target in zip(train_images["id"], train_images["label"]):
        if target!=show and show!="all":
            continue
        counter=counter+1
        if counter%100==0:
            break
        #Image loading from disk as JpegImageFile file format
        img=load_img(path, target_size=(IMG_WIDTH,IMG_HEIGHT))
        #Converting JpegImageFile to numpy array
        img=img_to_array(img)
        
        hside=get_side(img, side_type="horizontal")
        images.append(img)
        images.append(hside)

        if counter%10==0:
            himage=np.hstack((images))
            vside=get_side(himage, side_type="vertical")
            vertical_images.append(himage)
            vertical_images.append(vside)
            
            images=list()

    gallery=np.vstack((vertical_images)) 
    plt.figure(figsize=(12,12))
    plt.xticks([])
    plt.yticks([])
    title = {"all":"All Classifications's",
             "healthy":"Healthy",
             "covid":"Covid-19"}
    plt.title("100 Samples of {} Patients of the training set".format(title[show]))
    plt.imshow(gallery.astype(np.uint8))

# %%
#show_gallery("all")

# %%
def get_data_generator(dataframe, x_col, y_col, subset=None, shuffle=True, batch_size=32, class_mode="binary"):
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.05,
    horizontal_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1,
#     fill_mode='constant',
#     cval=0
    )
    
    data_generator = datagen.flow_from_dataframe(
        dataframe=dataframe,
        x_col=x_col,
        y_col=y_col,
        subset=subset,
        target_size=(IMG_WIDTH, IMG_HEIGHT),
        class_mode=class_mode,
        # color_mode="rgb",
        batch_size=batch_size,
        shuffle=shuffle
    )
    return data_generator

# %%
train_df, validation_df = get_data_set(0, SUB_FILE[0])
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = get_data_generator(example_df, "id", "label", class_mode = "categorical")
plt.figure(figsize = (12,12))
for i in range(0, 9):
        plt.subplot(3, 3, i+1)
        for X_batch, Y_batch in example_generator:
            image = X_batch[0]
            plt.imshow(image)
            break
plt.tight_layout()
plt.show()
# Out:
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1 validated image filenames belonging to 1 classes.

# %%
def get_model():
    with tf.device('/GPU:0'):
#         inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
#         s = tf.keras.layers.Lambda(lambda x: x/255)(inputs)
        
        classifier = tf.keras.Sequential()

        classifier.add(tf.keras.layers.Conv2D(32, (3, 3), input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))
#         classifier.add(MaxPooling2D(pool_size= (2,2)))

#         classifier.add(Convolution2D(64, (3, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.Conv2D(64, (3, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Conv2D(128, (3, 3), activation= 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'))
        classifier.add(tf.keras.layers.MaxPooling2D((2, 2)))

        classifier.add(tf.keras.layers.Flatten())

        classifier.add(tf.keras.layers.Dense(units= 512, activation= 'relu'))
        classifier.add(tf.keras.layers.Dropout(0.2))
        classifier.add(tf.keras.layers.Dense(units= 3, activation= 'sigmoid'))

        classifier.compile(optimizer= 'adam', loss= 'categorical_crossentropy' ,metrics= ['accuracy'])
        classifier.summary()

        return(classifier, 'simple')

# %%
def get_model_alexnet():
    with tf.device('/GPU:0'):
        model = tf.keras.Sequential()

        model.add(tf.keras.layers.Conv2D(96, kernel_size=(11,11), strides= 4, padding= 'valid', activation= 'relu', 
                                         input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), kernel_initializer= 'he_normal'))
        
        model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', 
                                               data_format= None))

        model.add(tf.keras.layers.Conv2D(256, kernel_size=(5,5), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))
        
        model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', 
                                               data_format= None)) 

        model.add(tf.keras.layers.Conv2D(384, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))

        model.add(tf.keras.layers.Conv2D(384, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))

        model.add(tf.keras.layers.Conv2D(256, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',
                                         kernel_initializer= 'he_normal'))

        model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', 
                                               data_format= None))

        model.add(tf.keras.layers.Flatten())
        model.add(tf.keras.layers.Dense(4096, activation= 'relu'))
        model.add(tf.keras.layers.Dense(4096, activation= 'relu'))
        model.add(tf.keras.layers.Dense(1000, activation= 'relu'))
        model.add(tf.keras.layers.Dense(units=3, activation= 'softmax'))

        model.compile(optimizer= tf.keras.optimizers.Adam(0.001), loss='categorical_crossentropy', 
                      metrics=['accuracy'])
        
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.summary()
        return(model, 'alexnet')

# %%
def get_model_vgg16():
        with tf.device('/GPU:0'):
            conv_base = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

            conv_base.trainable = True
            set_trainable = False
            for layer in conv_base.layers:
                if layer.name == 'conv3_block1_1_conv':
                    set_trainable = True
                if set_trainable:
                    layer.trainable = True
                else:
                    layer.trainable = False

            model = tf.keras.Sequential()
            model.add(conv_base)
            model.add(tf.keras.layers.GlobalAveragePooling2D())
            model.add(tf.keras.layers.Dense(units=3, activation = 'sigmoid'))

            model.compile(optimizer=optimizers.RMSprop(lr=2e-5), loss='binary_crossentropy', metrics=['accuracy'])
            model.summary()
            return (model, 'vgg16')

# %%
def train_model(model, train_df, validation_df, epochs, callbacks=[]):
    batch_size = 16
    train_generator = get_data_generator(train_df, "id", "label", batch_size=batch_size, class_mode="categorical")
    validation_generator = get_data_generator(validation_df, "id", "label", batch_size=batch_size, class_mode="categorical")

    step_size_train = train_generator.n // train_generator.batch_size
    step_size_validation = validation_generator.n // validation_generator.batch_size

    if step_size_train == 0:
        step_size_train = train_generator.n // 2
        step_size_validation = validation_generator.n // 2
        
    history = model.fit(train_generator, # X_Train
        steps_per_epoch=step_size_train,
        epochs=epochs, 
        validation_data=validation_generator,
        validation_steps=step_size_validation,
        callbacks=callbacks
   )
    return history.history

# %%
model, SELECTED_MODEL = get_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 198, 198, 32)      896
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 97, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 128)       147584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 2,635,203
# Trainable params: 2,635,203
# Non-trainable params: 0
# _________________________________________________________________

# %%
def plot_results(history, sub_folder, kfold, sel_model):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']

    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()
    plt.savefig('images/' + FOLDER_TEST + '/' + sub_folder + '/' + kfold + 'acc_'  + sel_model,
                pad_inches=0.1)
    
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and Validation loss')
    plt.legend()
    
    plt.savefig('images/' + FOLDER_TEST + '/' + sub_folder + '/' + kfold + 'loss_'  + sel_model, 
                orientation='portrait', pad_inches=0.1)

    plt.show()

# %%
for cur_subfolder in SUB_FILE:
    for set_number in [0, 1, 2, 3, 4]:
        print('\n\n\nTEST #\n=====')
        print(cur_subfolder, set_number)
        train_df, validation_df = get_data_set(set_number, cur_subfolder)
        history = train_model(model, train_df, validation_df, EPOCHS)
        plot_results(history, cur_subfolder, str(set_number), SELECTED_MODEL)
# Out:
# TEST #
# =====
# axis1 0
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/50
# 116/116 [==============================] - 19s 165ms/step - loss: 0.6914 - accuracy: 0.6953 - val_loss: 1.2030 - val_accuracy: 0.6551
# Epoch 2/50
# 116/116 [==============================] - 19s 163ms/step - loss: 0.1448 - accuracy: 0.9277 - val_loss: 2.3697 - val_accuracy: 0.7199
# Epoch 3/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0603 - accuracy: 0.9833 - val_loss: 2.7269 - val_accuracy: 0.7338
# Epoch 4/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0308 - accuracy: 0.9914 - val_loss: 3.6643 - val_accuracy: 0.7523
# Epoch 5/50
# 116/116 [==============================] - 19s 165ms/step - loss: 0.0494 - accuracy: 0.9865 - val_loss: 2.9167 - val_accuracy: 0.7176
# Epoch 6/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0272 - accuracy: 0.9935 - val_loss: 2.5082 - val_accuracy: 0.6875
# Epoch 7/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0321 - accuracy: 0.9892 - val_loss: 3.3488 - val_accuracy: 0.7338
# Epoch 8/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0097 - accuracy: 0.9957 - val_loss: 3.8240 - val_accuracy: 0.7338
# Epoch 9/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0333 - accuracy: 0.9930 - val_loss: 3.2614 - val_accuracy: 0.7431
# Epoch 10/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0043 - accuracy: 0.9978 - val_loss: 2.7847 - val_accuracy: 0.7616
# Epoch 11/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 2.9209 - val_accuracy: 0.7546
# Epoch 12/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0387 - accuracy: 0.9903 - val_loss: 2.7653 - val_accuracy: 0.7338
# Epoch 13/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 3.2675 - val_accuracy: 0.7500
# Epoch 14/50
# 116/116 [==============================] - 19s 164ms/step - loss: 0.
- val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 14/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 15/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 16/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 17/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 18/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 19/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 20/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5069
# Epoch 21/50
# 116/116 [==============================] - 19s 165ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 22/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 23/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 24/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 25/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 26/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 27/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 28/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 29/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 30/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 31/50
# 116/116 [==============================] - 19s 163ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 32/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 33/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 34/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5069
# Epoch 35/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5318 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 36/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 37/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 38/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 39/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 40/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 41/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 42/50
# 116/116 [==============================] - 19s 165ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 43/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 44/50
# 116/116 [==============================] - 19s 165ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 45/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 46/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 47/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 48/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 49/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 50/50
# 116/116 [==============================] - 19s 164ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# TEST #
# =====
# axis2 0
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/50
# 116/116 [==============================] - 63s 543ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 2/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 3/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 4/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 5/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5296 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 6/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 7/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 8/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 9/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 10/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 11/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 12/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 13/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 14/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 15/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5296 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 16/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 17/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5069
# Epoch 18/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 19/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 20/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 21/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4931
# Epoch 22/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5318 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 23/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 24/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 25/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 26/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 27/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5069
# Epoch 28/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 29/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 30/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 31/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 32/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 33/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 34/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 35/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 36/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 37/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 38/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 39/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 40/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 41/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 42/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 43/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 44/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5270 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 45/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 46/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 47/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 48/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 49/50
# 116/116 [==============================] - 20s 173ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 50/50
# 116/116 [==============================] - 20s 172ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# TEST #
# =====
# axis2 1
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/50
# ...
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 2/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 3/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 4/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5318 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 5/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 6/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 7/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 8/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 9/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 10/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 11/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 12/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 13/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 14/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 15/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 16/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 17/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 18/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 19/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 20/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5093
# Epoch 21/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 22/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 23/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 24/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 25/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 26/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 27/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4931
# Epoch 28/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 29/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5270 - val_loss: 1.1921e-07 - val_accuracy: 0.5069
# Epoch 30/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 31/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 32/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 33/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5318 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 34/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 35/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 36/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 37/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 38/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 39/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 40/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 41/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 42/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 43/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 44/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 45/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 46/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 47/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.4931
# Epoch 48/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 49/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5069
# Epoch 50/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# TEST #
# =====
# axis4 4
# Train fold with 1870 images
# label
# covid      990
# healthy    440
# others     440
# Name: label, dtype: int64
#
# Validation fold with 440 images
# label
# covid      220
# healthy    110
# others     110
# Name: label, dtype: int64
# ------------------------------
# Found 1870 validated image filenames belonging to 3 classes.
# Found 440 validated image filenames belonging to 3 classes.
# Epoch 1/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 2/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 3/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 4/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 5/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 6/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5275 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 7/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 8/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 9/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 10/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 11/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 12/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 13/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 14/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 15/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 16/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5318 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 17/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 18/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 19/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 20/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 21/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 22/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 23/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 24/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 25/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 26/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 27/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.4931
# Epoch 28/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 29/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 30/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 31/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5318 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 32/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.4977
# Epoch 33/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 34/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5280 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 35/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.4954
# Epoch 36/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5313 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 37/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 38/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 39/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 40/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 41/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 42/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 43/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 44/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5046
# Epoch 45/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 46/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5297 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 47/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5291 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 48/50
# 116/116 [==============================] - 20s 174ms/step - loss: 1.1921e-07 - accuracy: 0.5302 - val_loss: 1.1921e-07 - val_accuracy: 0.5000
# Epoch 49/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5286 - val_loss: 1.1921e-07 - val_accuracy: 0.5023
# Epoch 50/50
# 116/116 [==============================] - 20s 175ms/step - loss: 1.1921e-07 - accuracy: 0.5307 - val_loss: 1.1921e-07 - val_accuracy: 0.4931
