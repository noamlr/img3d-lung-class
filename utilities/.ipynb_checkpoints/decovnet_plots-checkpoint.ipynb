# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib

acc_text = 'accuracy'

def plot_results(df, title):
#     e = df['epoch']
    e = df['epoch']
    acc = df[acc_text]
    val_acc = df['val_'+acc_text]
#     val_auc = df['val_auc']

    plt.plot(e, acc, 'b', label='Training acc')
    plt.plot(e, val_acc, 'r', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()
    
    plt.show()

def plot_ss(df, title):
#     plt.ylim(0.5, 1.1)
    plt.ylim(0, 100)
    plt.title(title)
    sns.lineplot(data=df, x="epoch", y=acc_text, legend='brief', label='Acc')
    sns.lineplot(data=df, x="epoch", y="val_"+acc_text, legend='brief', label='Val_acc')
    plt.show()

# %%
# df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold6_ternary.csv')
df = pd.read_csv('../models/spgc-ternario-tf66-224x224/resnet101-bin_cross/fold/axis1/history.csv')
# df = pd.read_csv('../models/spgc-binario/resnet101/fold/axis2/history.csv')
# plot_results(df, '')
plot_ss(df, 'COVNet (dados: SPGC-Binário)')
print(df[df['val_'+acc_text]==max(df['val_'+acc_text])])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a2a9287ad952> in <module>
#       3 # df = pd.read_csv('../models/spgc-binario/resnet101/fold/axis2/history.csv')
#       4 # plot_results(df, '')
# ----> 5 plot_ss(df, 'COVNet (dados: SPGC-Binário)')
#       6 print(df[df['val_'+acc_text]==max(df['val_'+acc_text])])
#
# <ipython-input-4-22fbf84fc973> in plot_ss(df, title)
#      26     plt.ylim(0, 100)
#      27     plt.title(title)
# ---> 28     sns.lineplot(data=df, x="", y=acc_text, legend='brief', label='Acc')
#      29     sns.lineplot(data=df, x="", y="val_"+acc_text, legend='brief', label='Val_acc')
#      30     plt.show()
#
# ~/Documents/noa/cidia19/jupyter/env-cnn/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/Documents/noa/cidia19/jupyter/env-cnn/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     686         data=data, variables=variables,
#     687         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# --> 688         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#     689     )
#     690
#
# ~/Documents/noa/cidia19/jupyter/env-cnn/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~/Documents/noa/cidia19/jupyter/env-cnn/lib/python3.7/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/Documents/noa/cidia19/jupyter/env-cnn/lib/python3.7/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# ~/Documents/noa/cidia19/jupyter/env-cnn/lib/python3.7/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `` for parameter `x`

# %%
path = '../models/hh_bin_posindaty_neg_tf66/resnet101-bin_cross/fold{}/axis{}/history.csv'
for i in [1, 2, 3, 4, 5]:
    for j in [1, 2]:
        df = pd.read_csv(path.format(i, j))
        print("fold{}, axis{}".format(i, j))
        print(df[df['val_'+acc_text]==max(df['val_'+acc_text])])
# Out:
# fold1, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 6      6  0.042721         0.989574  1.060073             0.813234
# fold1, axis2
#    epoch     loss  binary_accuracy  val_loss  val_binary_accuracy
# 2      2  0.08456         0.978213  0.722641             0.820346
# fold2, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 7      7  0.025832          0.99253  0.411741             0.900433
# fold2, axis2
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 9      9  0.018205         0.995487  0.502781             0.869511
# fold3, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 5      5  0.044312         0.988796  0.449175             0.871058
# fold3, axis2
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 5      5  0.035878         0.991441  0.544302             0.867347
# fold4, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 1      1  0.180403          0.93369  0.579922              0.87312
# fold4, axis2
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 1      1  0.149649          0.94827  0.662071             0.864035
# fold5, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 8      8  0.020028         0.994338  0.481911             0.880013
# fold5, axis2
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 6      6  0.030517         0.991624   0.47148             0.879073

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold3.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold4.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold5.csv')
# plot_results(df, '')
plot_ss(df, '')
