# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib

def plot_results(df, title):
    e = df['epoch']
    acc = df['accuracy']
    val_acc = df['val_accuracy']
    val_auc = df['val_auc']

    plt.plot(e, acc, 'b', label='Training acc')
    plt.plot(e, val_acc, 'r', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()
    
    plt.show()

def plot_ss(df, title):
#     plt.ylim(0.5, 1.1)
    plt.ylim(0, 100)
    plt.title(title)
    sns.lineplot(data=df, x="epoch", y="accuracy", legend='brief', label='Acc')
    sns.lineplot(data=df, x="epoch", y="val_accuracy", legend='brief', label='Val_acc')
    plt.show()

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold6.csv')
# df = pd.read_csv('../models/spgc-ternario-42img/resnet101/fold/axis1/history.csv')
# df = pd.read_csv('../models/spgc-binario/resnet101/fold/axis2/history.csv')
# plot_results(df, '')
plot_ss(df, 'DeCovNet (dados: SPGC-Binário)')
print(df[df['val_accuracy']==max(df['val_accuracy'])])
# Out:
# <img src="data:image/png;base64,..." width="640">
#     epoch     loss  accuracy  val_loss  val_accuracy  val_auc
# 64    128  0.55286    73.276   0.55321        75.949    0.711
# 68    136  0.57357    66.810   0.55240        75.949    0.714
# 79    158  0.52569    72.414   0.55276        75.949    0.700

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold2.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold3.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold4.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold5.csv')
# plot_results(df, '')
plot_ss(df, '')
