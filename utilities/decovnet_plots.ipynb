# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib

acc_text = 'accuracy'

def plot_results(df, df2, title):
#     e = df['epoch']
    e = df['epoch']
    acc = df[acc_text]
    val_acc = df['val_'+acc_text]
#     val_auc = df['val_auc']

    plt.plot(e, acc, 'b', label='Training acc')
    plt.plot(e, val_acc, 'r', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()
    
    plt.show()

def plot_ss(df, df2, title):
    plt.ylim(0, 100)
#     plt.ylim(0, 1.1)
    plt.title(title)
    sns.lineplot(data=df2, x="epoch", y=acc_text, legend='brief', label='Acc')
    if df:
        sns.lineplot(data=df, x="epoch", y=acc_text, legend='brief', label='Acc_over')
    sns.lineplot(data=df2, x="epoch", y="val_"+acc_text, legend='brief', label='Val_acc')
    if df:
        sns.lineplot(data=df, x="epoch", y="val_"+acc_text, legend='brief', label='Val_acc_over')
    plt.show()

# %%
df2 = pd.read_csv('../csv/output/decovnet/decovnet-model/fold7spgc_bin.csv')
# df = pd.read_csv('../models/spgc-ternario-tf66-effnB6/efficientNetB6/fold/axis1/history.csv')
df = None
# df2 = pd.read_csv('../models/spgc-ternario-tf66-effnB6/efficientNetB6/fold/axis2/history.csv')
# df = pd.read_csv('../models/spgc-binario/resnet101/fold/axis2/history.csv')
# plot_results(df, '')
plot_ss(df, df2, 'DeCovNet covid vs. normal (Dataset SPGC-ICCASP)')
print(df2[df2['val_'+acc_text]==max(df2['val_'+acc_text])])
# Out:
# <img src="data:image/png;base64,..." width="640">
#      epoch    loss  val_loss  accuracy  val_accuracy  val_auc
# 63     126  0.5945    0.5825    71.552        75.949    0.708
# 72     144  0.6151    0.5798    67.241        75.949    0.683
# 84     168  0.5506    0.5715    73.707        75.949    0.700
# 86     172  0.5325    0.5603    71.552        75.949    0.709
# 87     174  0.5254    0.5659    75.000        75.949    0.699
# 124    248  0.4336    0.5443    79.310        75.949    0.715

# %%
path = '../models/hh_bin_posindaty_neg_tf66/resnet101-bin_cross/fold{}/axis{}/history.csv'
for i in [1, 2, 3, 4, 5]:
    for j in [1, 2]:
        df = pd.read_csv(path.format(i, j))
        print("fold{}, axis{}".format(i, j))
        print(df[df['val_'+acc_text]==max(df['val_'+acc_text])])
# Out:
# fold1, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 6      6  0.042721         0.989574  1.060073             0.813234
# fold1, axis2
#    epoch     loss  binary_accuracy  val_loss  val_binary_accuracy
# 2      2  0.08456         0.978213  0.722641             0.820346
# fold2, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 7      7  0.025832          0.99253  0.411741             0.900433
# fold2, axis2
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 9      9  0.018205         0.995487  0.502781             0.869511
# fold3, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 5      5  0.044312         0.988796  0.449175             0.871058
# fold3, axis2
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# 5      5  0.035878         0.991441  0.544302             0.867347
# fold4, axis1
#    epoch      loss  binary_accuracy  val_loss  val_binary_accuracy
# ...

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold3.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold4.csv')
# plot_results(df, '')
plot_ss(df, '')

# %%
df = pd.read_csv('../csv/output/decovnet/decovnet-model/fold5.csv')
# plot_results(df, '')
plot_ss(df, '')
