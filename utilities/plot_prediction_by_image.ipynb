# %%
DATE = '20201029'
AXIS = 'axis1'
MODEL = 'resnet101v2' # is resnet101 
PATH = f'../csv/output/{DATE}/{AXIS}/{MODEL}/predicted_by_image.csv'
ARR_COV = ['C21', 'C23', 'C25', 'C26', 'C27', 'C14', 'C32', 'C33', 'C35', 'C36', 'C39', 'C18', 'C41', 'C44', 'C49', 'C19', 'C20', 'C51', 'C60', 'C69', 'C71', 'C12', 'C74', 'C75', 'C77', 'C15', 'C79', 'C80', 'C82', 'C11', 'C83', 'C85', 'C88', 'C90', 'C91', 'C93', 'C94', 'C96', 'C13', 'C101', 'C103', 'C110', 'C111', 'C112', 'C113', 'C114', 'C115', 'C116', 'C117', 'C121', 'C124', 'C16', 'C125', 'C130', 'C131', 'C132', 'C17', 'C133', 'C135', 'C136', 'C138', 'C142', 'C143', 'C144', 'C145', 'C146', 'C149', 'C150', 'C151', 'C154', 'C155', 'C157', 'C158', 'C160', 'C161', 'C162', 'C163', 'TYP-020', 'TYP-022', 'TYP-026', 'TYP-025', 'TYP-009', 'TYP-021', 'TYP-024', 'TYP-028', 'TYP-006', 'TYP-005', 'TYP-013', 'TYP-029', 'TYP-018', 'TYP-030', 'TYP-016', 'TYP-007', 'TYP-019', 'TYP-011', 'TYP-023', 'TYP-004', 'TYP-017', 'TYP-010', 'TYP-015', 'TYP-012', 'TYP-014', 'TYP-031', 'TYP-002', 'TYP-003', 'TYP-008', 'TYP-027']
ARR_NON_COV = ['C22', 'C24', 'C28', 'C29', 'C30', 'C31', 'C34', 'C37', 'C38', 'C40', 'C42', 'C43', 'C45', 'C46', 'C47', 'C48', 'C50', 'C52', 'C54', 'C55', 'C56', 'C57', 'C58', 'C59', 'C61', 'C62', 'C63', 'C64', 'C65', 'C66', 'C67', 'C68', 'C70', 'C72', 'C73', 'C76', 'C78', 'C81', 'C84', 'C86', 'C9', 'C87', 'C89', 'C92', 'C97', 'C98', 'C99', 'C100', 'C5', 'C102', 'C104', 'C105', 'C106', 'C107', 'C108', 'C109', 'C3', 'C118', 'C119', 'C120', 'C122', 'C123', 'C126', 'C127', 'C128', 'C129', 'C134', 'C137', 'C139', 'C140', 'C141', 'C147', 'C148', 'C152', 'C156', 'C8', 'C159', 'C164', 'NEG-009', 'NEG-006', 'NEG-005', 'NEG-013', 'NEG-007', 'NEG-001', 'NEG-011', 'NEG-004', 'NEG-010', 'NEG-015', 'NEG-012', 'NEG-014', 'NEG-002', 'NEG-003', 'NEG-008', 'IND-020', 'IND-022', 'IND-026', 'IND-025', 'IND-009', 'IND-021', 'IND-024', 'IND-028', 'IND-006', 'IND-005', 'IND-013', 'IND-029', 'IND-018', 'IND-030', 'IND-016', 'IND-007', 'IND-001', 'IND-019', 'IND-011', 'IND-023', 'IND-004', 'IND-017', 'IND-010', 'IND-015', 'IND-012', 'IND-014', 'IND-002', 'IND-003', 'IND-008', 'IND-027', 'ATY-020', 'ATY-022', 'ATY-026', 'ATY-025', 'ATY-009', 'ATY-021', 'ATY-024', 'ATY-028', 'ATY-006', 'ATY-005', 'ATY-013', 'ATY-029', 'ATY-018', 'ATY-030', 'ATY-016', 'ATY-007', 'ATY-001', 'ATY-019', 'ATY-011', 'ATY-023', 'ATY-004', 'ATY-017', 'ATY-010', 'ATY-015', 'ATY-012', 'ATY-014', 'ATY-002', 'ATY-003', 'ATY-008', 'ATY-027']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
def plot_patients_preds(path):
    df = pd.read_csv(path)
    df = df * 100.0
    
    x_axis = df.index.to_list()
#     x_axis = np.linspace(0,82,82)
    it = 0
    for col in df.columns:
        it += 1
        y_axis = df[col]
#         print(x_axis, y_axis)
#         if it > 20: break
        is_covid = 'non covid'
        if col in ARR_COV: is_covid = 'covid'
        plt.plot(x_axis, y_axis, 'bo', label='')
        plt.ylim(ymin=0)
        plt.title('Grau de Confianca por fatia do paciente ' + col + ' - ' + is_covid)
        plt.show()

# %%
plot_patients_preds(PATH)
